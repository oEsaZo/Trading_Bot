# %%
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xzvf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# !pip install Ta-Lib
#download and install modules
# Out:
# --2022-02-14 03:36:23--  http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# Resolving prdownloads.sourceforge.net (prdownloads.sourceforge.net)... 204.68.111.105
# Connecting to prdownloads.sourceforge.net (prdownloads.sourceforge.net)|204.68.111.105|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz [following]
# --2022-02-14 03:36:23--  http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz
# Resolving downloads.sourceforge.net (downloads.sourceforge.net)... 204.68.111.105
# Reusing existing connection to prdownloads.sourceforge.net:80.
# HTTP request sent, awaiting response... 302 Found
# Location: http://iweb.dl.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz [following]
# --2022-02-14 03:36:23--  http://iweb.dl.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz
# ...

# %%
# !pip install python-binance
#binance module
# Out:
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 11.7 MB/s
# ...
#      |████████████████████████████████| 288 kB 56.7 MB/s
# ...
#      |████████████████████████████████| 103 kB 54.1 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 271 kB 57.6 MB/s
# ...
#      |████████████████████████████████| 144 kB 40.5 MB/s
# ...

# %%
import talib
import websocket
import json
import binance
import pprint
import numpy
#import some modules

# %%
SOCKET = "wss://stream.binance.com:9443/ws/maticusdt@kline_1m"
RSI_PERIOD = 70
RSI_OVER = 30
TRADE_SYMBOL = "MATICUSDT"
TRADE_QUANTITY = 10

closes=[]
def on_open(ws):
    print('opened connection')

def on_close(ws):
    print('closed connection')

def on_message(ws, message):
    global closes
    print('recieved message')
    json_message  = json.loads(message)
    pprint.pprint(json_message)

    candle = json_message['k']

    is_candle_closed = candle['x']
    close = candle['c']
    closes.append(float(close))

    if is_candle_closed:
        print("candle closed at {}".format(close))

ws = websocket.WebSocketApp(SOCKET , on_open=on_open , on_close=on_close,on_message=on_message)
ws.run_forever()
# Out:
# opened connection
# recieved message
# {'E': 1644822859406,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 240356761,
#        'Q': '3544.59800000',
#        'T': 1644822899999,
#        'V': '2174.60000000',
#        'c': '1.63000000',
#        'f': 240356729,
#        'h': '1.63100000',
#        'i': '1m',
#        'l': '1.62900000',
#        'n': 33,
#        'o': '1.63100000',
#        'q': '21740.62740000',
#        's': 'MATICUSDT',
#        't': 1644822840000,
#        'v': '13333.90000000',
#        'x': False},
#  's': 'MATICUSDT'}
# recieved message
# {'E': 1644822861714,
#  'e': 'kline',
#  'k': {'B': '0',
#        'L': 240356816,
#        'Q': '4738.73600000',
#        'T': 1644822899999,
#        'V': '2907.20000000',
#        'c': '1.63000000',
#        'f': 240356729,
#        'h': '1.63100000',
#        'i': '1m',
#        'l': '1.62900000',
#        'n': 88,
#        'o': '1.63100000',
#        'q': '23006.32240000',
#        's': 'MATICUSDT',
# ...

# %%
import requests # Install requests module firstly

url = "https://api.coindcx.com/exchange/ticker"

response = requests.get(url)
data = response.json()
print(data)

response = requests.get(url)
data1 = response.json()
print(data1)
# Out:
# [{'market': 'BTCINR', 'change_24_hour': '-0.759', 'high': '3399495.35', 'low': '3306000.01', 'volume': '385169466.4296237', 'last_price': '3356915.48', 'bid': '3356915.480000', 'ask': '3360893.210000', 'timestamp': 1644842621}, {'market': 'MITHBTC', 'change_24_hour': '-3.226', 'high': '0.00000096', 'low': '0.00000089', 'volume': '17.77894369', 'last_price': '0.00000090', 'bid': '0.00000089', 'ask': '0.00000090', 'timestamp': 1644842621}, {'market': 'SNTBTC', 'change_24_hour': '-8.276', 'high': '0.00000145', 'low': '0.00000132', 'volume': '8.12181167', 'last_price': '0.00000133', 'bid': '0.00000133', 'ask': '0.00000134', 'timestamp': 1644842621}, {'market': 'NESTETH', 'change_24_hour': '1.698', 'high': '0.00000588', 'low': '0.00000523', 'volume': '17.0691134888', 'last_price': '0.00000539', 'bid': '0.00000532', 'ask': '0.00000537', 'timestamp': 1644842621}, {'market': 'XRPINR', 'change_24_hour': '-6.079', 'high': '67.02', 'low': '62.0', 'volume': '2683414.29', 'last_price': '62.880000
# ...

# %%
import requests # Install requests module first.

url = "https://api.coindcx.com/exchange/v1/markets"

response = requests.get(url)
data = response.json()
print(data)
# Out:
# ['NESTETH', 'XRPINR', 'AGLDUSDT', 'CEREUSDT', 'THETAINR', 'IICBTC', 'USDTINR', 'SOSINR', 'RSRBTC', 'MLNUSDT', 'ATOMETH', 'RADARUSDT', 'XTMUSDT', 'BTCINR', 'BANDETH', 'MTAUSDT', 'PUSHBTC', '1SOLUSDT', 'FORUSDT', 'DFAUSDT', 'CMTUSDT', 'TTBTC', 'ELABTC', 'TLMBUSD', 'XNOBTC', 'RSRUSDT', 'DGDETH', 'DOGEINR', 'YFIETH', 'HTUSDT', 'TTUSDT', 'ELAUSDT', 'SHIBINR', 'AURYUSDT', 'GXCUSDT', 'BSVUSDT', 'FOXUSDT', 'ACTUSDT', 'FSNBTC', 'CROUSDT', 'MGGUSDT', 'ITCBTC', 'OPULUSDT', 'GXCBTC', 'FRONTUSDT', 'GALAINR', 'PUSHUSDT', 'MATICINR', 'ANTETH', 'AEUSDT', 'YFIIETH', 'NEXOUSDT', 'SWFTCBTC', 'AGLDBTC', 'RCNBTC', 'TNBETH', 'MLNBTC', 'SOLINR', 'GRTINR', 'RAINUSDT', 'ENSUSDT', 'ETHINR', 'HTBTC', 'ARBTC', 'LITHUSDT', 'MLNETH', 'SNXETH', 'BSVBTC', 'ETNBTC', 'HCUSDT', 'GALUSDT', 'MTAETH', 'PUSHINR', 'FRONTBTC', 'IOTXINR', 'CMTETH', 'MTABTC', 'ARETH', 'HCBTC', 'FSNUSDT', 'SOSUSDT', 'ADAINR', 'NTUSDT', 'HOTINR', 'OMGINR', 'XMRETH', 'IMXBUSD', 'ATOMBUSD', 'AUDIOBTC', 'GHSTUSDT', 'SUSHIBNB', 'PLABUSD', 'MITHBTC'
# ...

# %%
import requests # Install requests module first.

url = "https://public.coindcx.com/market_data/candles?pair=B-BTC_USDT&interval=1m" # Replace 'SNTBTC' with the desired market pair.

response = requests.get(url)
data = response.json()
print(data)
len(data)
# Out:
# [{'open': 42395.94, 'high': 42412.19, 'low': 42384.26, 'volume': 19.27325, 'close': 42401.2, 'time': 1644842880000}, {'open': 42444.2, 'high': 42460.31, 'low': 42390.97, 'volume': 60.54442, 'close': 42395.94, 'time': 1644842820000}, {'open': 42473.02, 'high': 42506.81, 'low': 42428.42, 'volume': 115.14177, 'close': 42444.19, 'time': 1644842760000}, {'open': 42389.95, 'high': 42515.53, 'low': 42389.95, 'volume': 130.06102, 'close': 42473.03, 'time': 1644842700000}, {'open': 42448.96, 'high': 42455.99, 'low': 42381.01, 'volume': 77.20866, 'close': 42389.96, 'time': 1644842640000}, {'open': 42362.16, 'high': 42500, 'low': 42357.83, 'volume': 217.0749, 'close': 42448.96, 'time': 1644842580000}, {'open': 42430, 'high': 42441.95, 'low': 42358.76, 'volume': 94.8706, 'close': 42362.17, 'time': 1644842520000}, {'open': 42330.56, 'high': 42431.19, 'low': 42327.43, 'volume': 89.1743, 'close': 42430, 'time': 1644842460000}, {'open': 42287.8, 'high': 42389.99, 'low': 42274.04, 'volume': 140.06751
# ...

# %%
pip install socketio
# Out:
# ...
#      |████████████████████████████████| 545 kB 4.1 MB/s
# ...
#   Created wheel for socketio: filename=socketio-0.2.1-py3-none-any.whl size=7690 sha256=fdc0a9ca07de68379d4821566610b66306a8ce5802ee9820b137c0f828deb789
#   Stored in directory: /root/.cache/pip/wheels/ab/10/a2/24aa1b2b056ad09b35eb1244e6dac4a6eddc74b85fdcf45589
# ...
#   Created wheel for netifaces: filename=netifaces-0.10.6-cp37-cp37m-linux_x86_64.whl size=37051 sha256=eff5490ea568de9d4aadaae79818b0b843089dd58040ad0b0f0ab7aeb19627c8
#   Stored in directory: /root/.cache/pip/wheels/bb/8a/7d/60fbc89c02739aa43ee2fcf373140dadf627c11a67183c4d22
# Successfully built socketio netifaces
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import socketio

def my_headers():
    return {"origin": "*"}

socketEndpoint = 'https://stream.coindcx.com'
sio = socketio.Client()

sio.connect(socketEndpoint, transports = 'websocket')
sio.emit('join', { 'channelName': 'channelName' })

# Listen update on channelName
@sio.on('channelName')
def on_message(response):
    print(response.data)

# leave a channel
sio.emit('leave', { 'channelName' : 'B-SNM_BTC' })

# Successfull connection
@sio.event
def connect():
    print("I'm connected!")

# Connection error if any found
@sio.event
def connect_error(data):
    print("The connection failed!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4fc9e2a476e6> in <module>()
#       5
#       6 socketEndpoint = 'https://stream.coindcx.com'
# ----> 7 sio = socketio.Client()
#       8
#       9 sio.connect(socketEndpoint, transports = 'websocket')
#
# AttributeError: module 'socketio' has no attribute 'Client'

# %%
curl --request POST -u$uePJBXIcEj4vW2MdVhFI8H8r5:$LwrMCILfdZyL4ThOCYV8vKKoufJlBusgxsuUjbESbCrfJJNxMG \
  --url 'https://api.twitter.com/oauth2/token?grant_type=client_credentials'
# Out:
#   File "<ipython-input-2-c8343a1ca9c1>", line 1
#     curl --request POST -u$uePJBXIcEj4vW2MdVhFI8H8r5:$LwrMCILfdZyL4ThOCYV8vKKoufJlBusgxsuUjbESbCrfJJNxMG   --url 'https://api.twitter.com/oauth2/token?grant_type=client_credentials'
#                       ^
# SyntaxError: invalid syntax
